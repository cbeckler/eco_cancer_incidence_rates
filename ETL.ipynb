# %% [markdown]
# <a href="https://colab.research.google.com/github/cbeckler/final_project/blob/cb_etl/ETL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
# Find the latest version of spark 3.0 from http://www.apache.org/dist/spark/ and enter as the spark version
# For example:
# spark_version = 'spark-3.0.3'
spark_version = 'spark-3.1.3'
os.environ['SPARK_VERSION']=spark_version

# Install Spark and Java
# !apt-get update
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q http://www.apache.org/dist/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop2.7.tgz
# !tar xf $SPARK_VERSION-bin-hadoop2.7.tgz
# !pip install -q findspark

# Set Environment Variables
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-hadoop2.7"

# Start a SparkSession
import findspark
findspark.init()
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:10 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Get:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:14 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [2,240 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [1,349 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,573 kB]
# Get:17 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [1,145 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [3,127 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,348 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [30.8 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,552 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [1,392 kB]
# Get:23 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [43.2 kB]
# Fetched 17.1 MB in 7s (2,592 kB/s)
# Reading package lists... Done

# %%
# Download the Postgres driver that will allow Spark to interact with Postgres.
# !wget https://jdbc.postgresql.org/download/postgresql-42.2.16.jar
# Out:
# --2023-01-10 00:56:36--  https://jdbc.postgresql.org/download/postgresql-42.2.16.jar
# Resolving jdbc.postgresql.org (jdbc.postgresql.org)... 72.32.157.228, 2001:4800:3e1:1::228
# Connecting to jdbc.postgresql.org (jdbc.postgresql.org)|72.32.157.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1002883 (979K) [application/java-archive]
# Saving to: ‘postgresql-42.2.16.jar’
#
# postgresql-42.2.16. 100%[===================>] 979.38K  2.99MB/s    in 0.3s
#
# 2023-01-10 00:56:37 (2.99 MB/s) - ‘postgresql-42.2.16.jar’ saved [1002883/1002883]

# %%
# start spark session that can connect to postgre
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("final-project").config("spark.driver.extraClassPath","/content/postgresql-42.2.16.jar").getOrCreate()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# import cancer data

cancer_path = "/content/drive/MyDrive/Data/cancer_incidence.csv"

cancer_df = pd.read_csv(cancer_path)

cancer_df.head()
# Out:
#    index                         County   FIPS  \
# 0      0           US (SEER+NPCR)(1,10)      0
# 1      1  Autauga County, Alabama(6,10)   1001
# 2      2  Baldwin County, Alabama(6,10)   1003
# 3      3  Barbour County, Alabama(6,10)   1005
# 4      4     Bibb County, Alabama(6,10)   1007
#
#   Age-Adjusted Incidence Rate(Ê) - cases per 100,000  \
# 0                                               62.4
# 1                                               74.9
# 2                                               66.9
# 3                                               74.6
# 4                                               86.4
#
#   Lower 95% Confidence Interval Upper 95% Confidence Interval  \
# 0                          62.3                          62.6
# 1                          65.1                          85.7
# 2                          62.4                          71.7
# 3                          61.8                          89.4
# 4                            71                         104.2
#
#   Average Annual Count Recent Trend  \
# 0               214614      falling
# 1                   43       stable
# 2                  170       stable
# 3                   25       stable
# 4                   23       stable
#
#   Recent 5-Year Trend (ˆ) in Incidence Rates Lower 95% Confidence Interval.1  \
# 0                                       -2.5                              -3
# 1                                        0.5                           -14.9
# 2                                          3                           -10.2
# 3                                       -6.4                           -18.3
# 4                                       -4.5                           -31.4
#
#   Upper 95% Confidence Interval.1
# 0                              -2
# 1                            18.6
# 2                            18.3
# 3                             7.3
# 4                            32.9

# %%
# get rid of recent trend nulls (stored as *, _, __)

cancer_df = cancer_df.loc[(cancer_df['Recent Trend']=='rising')|(cancer_df['Recent Trend']=='falling')|(cancer_df['Recent Trend']=='stable')]

# drop unusued columns and rename vars

cancer_df = cancer_df[[' FIPS', 'Recent Trend']].copy()

cancer_df = cancer_df.rename(columns={' FIPS':'FIPS', 'Recent Trend':'recent_trend'})

cancer_df['recent_trend'].value_counts()
# Out:
# stable     2429
# falling     200
# rising       43
# Name: recent_trend, dtype: int64

# %%
# import pm data

pm_path = "/content/drive/MyDrive/Data/Daily_PM2.5_Concentrations_All_County__2001-2016.csv"

pm_df = pd.read_csv(pm_path)

pm_df.head()
# Out:
#    year       date  statefips  countyfips  PM25_max_pred  PM25_med_pred  \
# 0  2001  01JAN2001          1           1      10.664367      10.264546
# 1  2001  01JAN2001          1           3       9.803209       8.739505
# 2  2001  01JAN2001          1           5      12.087599      11.809159
# 3  2001  01JAN2001          1           7       8.579425       8.435394
# 4  2001  01JAN2001          1           9      14.399446      13.577741
#
#    PM25_mean_pred  PM25_pop_pred
# 0       10.137631      10.188703
# 1        8.743748       8.811486
# 2       11.812775      11.802062
# 3        8.458118       8.448871
# 4       13.300528      13.231461

# %%
# import ozone data

oz_path = "/content/drive/MyDrive/Data/Daily_County-Level_Ozone_Concentrations__2001-2016.csv"

oz_df = pd.read_csv(oz_path)

oz_df.head()
# Out:
#    Year Month  Day  statefips  countyfips  O3_max_pred  O3_med_pred  \
# 0  2001   JAN    1          1           1    31.939058    31.691988
# 1  2001   JAN    1          1           3    33.646855    33.170271
# 2  2001   JAN    1          1           5    34.288917    34.068507
# 3  2001   JAN    1          1           7    30.349767    30.036093
# 4  2001   JAN    1          1           9    26.472655    25.776595
#
#    O3_mean_pred  O3_pop_pred
# 0     31.680859    31.671226
# 1     32.994775    32.935070
# 2     34.077954    34.086631
# 3     29.931756    29.991733
# 4     25.857571    25.872472

# %%
# filter pollution data for years matching cancer data
# it was found med_pred > 100 were outlier values
pm_df = pm_df.loc[(pm_df['year']<=2014)&(pm_df['PM25_med_pred']<=100)]

# %%
# check years to ensure they match cancer data range
pm_df.year.unique()
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014])

# %%
# create state + county FIPS to match cancer data FIPS

pm_df['FIPS_pm'] = pm_df['statefips'].astype(str) + pm_df['countyfips'].astype(str)

pm_df['FIPS_pm'] = pm_df['FIPS_pm'].astype(int)

pm_df.head()
# Out:
#    year       date  statefips  countyfips  PM25_max_pred  PM25_med_pred  \
# 0  2001  01JAN2001          1           1      10.664367      10.264546
# 1  2001  01JAN2001          1           3       9.803209       8.739505
# 2  2001  01JAN2001          1           5      12.087599      11.809159
# 3  2001  01JAN2001          1           7       8.579425       8.435394
# 4  2001  01JAN2001          1           9      14.399446      13.577741
#
#    PM25_mean_pred  PM25_pop_pred  FIPS_pm
# 0       10.137631      10.188703       11
# 1        8.743748       8.811486       13
# 2       11.812775      11.802062       15
# 3        8.458118       8.448871       17
# 4       13.300528      13.231461       19

# %%
# aggregate pollution data by county

pm_agg = pm_df.groupby('FIPS_pm').agg({'PM25_max_pred':'mean', 'PM25_med_pred':'mean', 'PM25_mean_pred':'mean'})

pm_agg.reset_index(inplace=True)

pm_agg.head()
# Out:
#    FIPS_pm  PM25_max_pred  PM25_med_pred  PM25_mean_pred
# 0       11      12.239594      11.870589       11.787900
# 1       13      11.024418       9.822870        9.794272
# 2       15      11.688170      11.099414       11.084238
# 3       17      12.280141      11.700512       11.721958
# 4       19      13.498799      12.690525       12.741736

# %%
# aggregate pollution data by county and year

pm_year_agg = pm_df.groupby(['FIPS_pm', 'year']).agg({'PM25_max_pred':'mean', 'PM25_med_pred':'mean', 'PM25_mean_pred':'mean'})

pm_year_agg.reset_index(inplace=True)

pm_year_agg.head()
# Out:
#    FIPS_pm  year  PM25_max_pred  PM25_med_pred  PM25_mean_pred
# 0       11  2001      13.186807      12.834644       12.784293
# 1       11  2002      12.490668      12.162930       12.068693
# 2       11  2003      12.869481      12.485005       12.400802
# 3       11  2004      13.111945      12.716436       12.619426
# 4       11  2005      13.543276      13.164472       13.071456

# %%
# long to wide format

pm_year_agg = pd.melt(pm_year_agg, id_vars=['FIPS_pm', 'year'], value_vars=['PM25_max_pred', 'PM25_med_pred', 'PM25_mean_pred'])

pm_year_agg['col_name'] = pm_year_agg['variable'] + '_' + pm_year_agg['year'].astype(str)

pm_year_agg = pm_year_agg.pivot(index='FIPS_pm', columns='col_name', values='value')

pm_year_agg.reset_index(inplace=True)

pm_year_agg.head()
# Out:
# col_name  FIPS_pm  PM25_max_pred_2001  PM25_max_pred_2002  PM25_max_pred_2003  \
# 0              11           13.186807           12.490668           12.869481
# 1              13           12.520190           11.269680           12.162325
# 2              15           12.364383           11.443971           11.531937
# 3              17           13.944184           12.781192           13.162910
# 4              19           16.032861           14.493547           14.722058
#
# col_name  PM25_max_pred_2004  PM25_max_pred_2005  PM25_max_pred_2006  \
# 0                  13.111945           13.543276           13.638252
# 1                  12.081706           12.994364           11.942907
# 2                  12.543327           12.787813           12.915748
# 3                  13.082518           14.310805           14.060887
# 4                  14.622386           15.809701           15.465637
#
# col_name  PM25_max_pred_2007  PM25_max_pred_2008  PM25_max_pred_2009  ...  \
# 0                  14.542888           12.507304           10.279905  ...
# 1                  12.256714           10.514962            9.342412  ...
# 2                  14.095731           11.702072           10.480079  ...
# 3                  14.206462           12.319946            9.992209  ...
# 4                  16.052929           13.357497           10.911080  ...
#
# col_name  PM25_med_pred_2005  PM25_med_pred_2006  PM25_med_pred_2007  \
# 0                  13.164472           13.224270           14.036194
# 1                  11.503305           10.513930           10.622514
# 2                  12.087744           12.229105           13.112620
# 3                  13.484249           13.370442           13.508796
# 4                  14.797208           14.530090           15.028200
#
# col_name  PM25_med_pred_2008  PM25_med_pred_2009  PM25_med_pred_2010  \
# 0                  12.022979           10.003785           10.788455
# 1                   9.247900            8.429134            8.885592
# 2                  11.074860            9.945611           10.689897
# 3                  11.717692            9.575728           10.485379
# 4                  12.598568           10.283973           11.372750
#
# col_name  PM25_med_pred_2011  PM25_med_pred_2012  PM25_med_pred_2013  \
# 0                  10.808470           10.438640           10.220977
# 1                   8.865912            8.737817            8.437009
# 2                  10.289959            9.641680            9.644445
# 3                  10.607298            9.992089            9.996376
# 4                  11.053671           10.687267           10.306375
#
# col_name  PM25_med_pred_2014
# 0                  11.282171
# 1                   9.635918
# 2                  10.925400
# 3                  10.747303
# 4                  10.994724
#
# [5 rows x 43 columns]

# %%
# Remove years after 2014 to match cancer data
# no ozone outliers were found in the data
oz_df = oz_df[oz_df['Year']<=2014]

# %%
oz_df.Year.unique()
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014])

# %%
# create state + county FIPS to match cancer data FIPS

oz_df['FIPS_oz'] = oz_df['statefips'].astype(str) + oz_df['countyfips'].astype(str)

oz_df['FIPS_oz'] = oz_df['FIPS_oz'].astype(int)

oz_df.head()
# Out:
#    Year Month  Day  statefips  countyfips  O3_max_pred  O3_med_pred  \
# 0  2001   JAN    1          1           1    31.939058    31.691988
# 1  2001   JAN    1          1           3    33.646855    33.170271
# 2  2001   JAN    1          1           5    34.288917    34.068507
# 3  2001   JAN    1          1           7    30.349767    30.036093
# 4  2001   JAN    1          1           9    26.472655    25.776595
#
#    O3_mean_pred  O3_pop_pred  FIPS_oz
# 0     31.680859    31.671226       11
# 1     32.994775    32.935070       13
# 2     34.077954    34.086631       15
# 3     29.931756    29.991733       17
# 4     25.857571    25.872472       19

# %%
#aggreagate ozone data by county

oz_agg = oz_df.groupby(['FIPS_oz']).agg({'O3_max_pred':'mean','O3_med_pred':'mean','O3_mean_pred':'mean'})

oz_agg.reset_index(inplace=True)

oz_agg.head()
# Out:
#    FIPS_oz  O3_max_pred  O3_med_pred  O3_mean_pred
# 0       11    41.001571    39.948742     39.921898
# 1       13    45.070022    41.241604     41.341833
# 2       15    41.139416    40.185889     40.162437
# 3       17    40.505549    39.399455     39.389288
# 4       19    42.714107    41.096201     41.085945

# %%
# aggregate ozone data by county and year

oz_year_agg = oz_df.groupby(['FIPS_oz', 'Year']).agg({'O3_max_pred':'mean','O3_med_pred':'mean','O3_mean_pred':'mean'})

oz_year_agg.reset_index(inplace=True)

oz_year_agg.head()
# Out:
#    FIPS_oz  Year  O3_max_pred  O3_med_pred  O3_mean_pred
# 0       11  2001    42.305986    41.322810     41.306320
# 1       11  2002    41.864027    40.669792     40.647115
# 2       11  2003    40.068504    38.835014     38.825136
# 3       11  2004    39.985884    38.801989     38.819420
# 4       11  2005    41.686453    40.529218     40.518377

# %%
# long to wide format

oz_year_agg = pd.melt(oz_year_agg, id_vars=['FIPS_oz', 'Year'], value_vars=['O3_max_pred', 'O3_med_pred', 'O3_mean_pred'])

oz_year_agg['col_name'] = oz_year_agg['variable'] + '_' + oz_year_agg['Year'].astype(str)

oz_year_agg = oz_year_agg.pivot(index='FIPS_oz', columns='col_name', values='value')

oz_year_agg.reset_index(inplace=True)

oz_year_agg.head()
# Out:
# col_name  FIPS_oz  O3_max_pred_2001  O3_max_pred_2002  O3_max_pred_2003  \
# 0              11         42.305986         41.864027         40.068504
# 1              13         46.301171         44.590730         45.091291
# 2              15         42.835619         40.764086         39.282389
# 3              17         41.606691         41.316442         39.441656
# 4              19         43.658069         43.200936         43.007695
#
# col_name  O3_max_pred_2004  O3_max_pred_2005  O3_max_pred_2006  \
# 0                39.985884         41.686453         44.962250
# 1                45.814931         47.630605         49.781161
# 2                40.656445         41.673038         44.833797
# 3                39.402323         42.373669         44.924412
# 4                41.240142         42.970437         45.503027
#
# col_name  O3_max_pred_2007  O3_max_pred_2008  O3_max_pred_2009  ...  \
# 0                45.038095         41.422075         37.122685  ...
# 1                47.312026         44.124541         42.082399  ...
# 2                44.750438         42.070679         38.118018  ...
# 3                44.941542         40.942346         36.030710  ...
# 4                46.806477         43.306486         38.762750  ...
#
# col_name  O3_med_pred_2005  O3_med_pred_2006  O3_med_pred_2007  \
# 0                40.529218         43.681686         43.838816
# 1                43.565735         45.922312         43.525804
# 2                40.585246         43.720973         43.837824
# 3                41.133554         43.764713         43.850361
# 4                41.301827         43.677824         45.038788
#
# col_name  O3_med_pred_2008  O3_med_pred_2009  O3_med_pred_2010  \
# 0                40.486148         36.221797         41.289135
# 1                40.236525         38.505225         42.373774
# 2                41.187681         37.317680         41.459194
# 3                39.875838         35.059151         39.827738
# 4                41.869574         37.462589         42.542686
#
# col_name  O3_med_pred_2011  O3_med_pred_2012  O3_med_pred_2013  \
# 0                40.862455         39.302231         36.364677
# 1                42.022552         39.985824         37.438556
# 2                41.776717         39.300123         36.652613
# 3                39.680734         38.873873         35.961584
# 4                41.728563         41.646953         37.739042
#
# col_name  O3_med_pred_2014
# 0                37.080065
# 1                38.104659
# 2                37.449995
# 3                36.127933
# 4                38.077132
#
# [5 rows x 43 columns]

# %%
# get row count of initial df

len(cancer_df)
# Out:
# 2672

# %%
# merge cancer and pollution data

final_df = pd.merge(cancer_df, pm_agg, how='inner', left_on='FIPS', right_on='FIPS_pm')

final_df.head()
# Out:
#    FIPS recent_trend  FIPS_pm  PM25_max_pred  PM25_med_pred  PM25_mean_pred
# 0  1101      falling     1101      12.555164      12.013325       11.958884
# 1  1103       stable     1103      13.287901      12.684610       12.647047
# 2  1105       stable     1105      11.426605      11.072150       11.079387
# 3  1107       stable     1107      11.594499      11.146401       11.155309
# 4  1109       stable     1109      11.352271      10.939546       10.932512

# %%
# get row count of matches

len(final_df)
# Out:
# 1048

# %%
# merge ozone data

final_df = pd.merge(final_df, oz_agg, how='inner', left_on='FIPS', right_on='FIPS_oz')

final_df.head()
# Out:
#    FIPS recent_trend  FIPS_pm  PM25_max_pred  PM25_med_pred  PM25_mean_pred  \
# 0  1101      falling     1101      12.555164      12.013325       11.958884
# 1  1103       stable     1103      13.287901      12.684610       12.647047
# 2  1105       stable     1105      11.426605      11.072150       11.079387
# 3  1107       stable     1107      11.594499      11.146401       11.155309
# 4  1109       stable     1109      11.352271      10.939546       10.932512
#
#    FIPS_oz  O3_max_pred  O3_med_pred  O3_mean_pred
# 0     1101    41.874165    39.939759     39.977164
# 1     1103    43.308170    41.901690     41.888594
# 2     1105    39.805057    38.986625     39.022229
# 3     1107    39.979953    39.173487     39.137133
# 4     1109    40.690546    39.856677     39.866958

# %%
# get count of matches

len(final_df)
# Out:
# 1048

# %%
# get count of label distribution

final_df['recent_trend'].value_counts()
# Out:
# stable     961
# falling     68
# rising      19
# Name: recent_trend, dtype: int64

# %%
# merge year data

final_df = pd.merge(final_df, pm_year_agg, how='left', left_on='FIPS', right_on='FIPS_pm')

final_df = pd.merge(final_df, oz_year_agg, how='left', left_on='FIPS', right_on='FIPS_oz')

final_df.head()
# Out:
#    FIPS recent_trend  FIPS_pm_x  PM25_max_pred  PM25_med_pred  PM25_mean_pred  \
# 0  1101      falling       1101      12.555164      12.013325       11.958884
# 1  1103       stable       1103      13.287901      12.684610       12.647047
# 2  1105       stable       1105      11.426605      11.072150       11.079387
# 3  1107       stable       1107      11.594499      11.146401       11.155309
# 4  1109       stable       1109      11.352271      10.939546       10.932512
#
#    FIPS_oz_x  O3_max_pred  O3_med_pred  O3_mean_pred  ...  O3_med_pred_2005  \
# 0       1101    41.874165    39.939759     39.977164  ...         40.567937
# 1       1103    43.308170    41.901690     41.888594  ...         43.226680
# 2       1105    39.805057    38.986625     39.022229  ...         40.612558
# 3       1107    39.979953    39.173487     39.137133  ...         41.574587
# 4       1109    40.690546    39.856677     39.866958  ...         40.589950
#
#    O3_med_pred_2006  O3_med_pred_2007  O3_med_pred_2008  O3_med_pred_2009  \
# 0         43.333084         43.589498         40.750847         36.326936
# 1         44.786660         46.470120         42.158683         38.435499
# 2         43.447473         43.062623         38.970321         34.915892
# 3         43.677365         42.648266         38.709791         35.148054
# 4         43.572161         43.102934         40.463900         36.734288
#
#    O3_med_pred_2010  O3_med_pred_2011  O3_med_pred_2012  O3_med_pred_2013  \
# 0         41.478252         41.055674         39.470118         36.512861
# 1         42.927004         42.164915         41.937580         38.473920
# 2         39.396689         38.999311         37.908802         35.517161
# 3         39.154417         38.971029         38.468993         36.022568
# 4         41.022877         40.996091         38.420984         36.382191
#
#    O3_med_pred_2014
# 0         37.457633
# 1         38.021493
# 2         35.654156
# 3         35.750203
# 4         37.127240
#
# [5 rows x 96 columns]

# %%
# drop dup FIPS columns and return list of all cols

final_df.drop(columns=['FIPS_oz_x', 'FIPS_oz_y', 'FIPS_pm_x', 'FIPS_pm_y'], inplace=True)

final_df.columns
# Out:
# Index(['FIPS', 'recent_trend', 'PM25_max_pred', 'PM25_med_pred',
#        'PM25_mean_pred', 'O3_max_pred', 'O3_med_pred', 'O3_mean_pred',
#        'PM25_max_pred_2001', 'PM25_max_pred_2002', 'PM25_max_pred_2003',
#        'PM25_max_pred_2004', 'PM25_max_pred_2005', 'PM25_max_pred_2006',
#        'PM25_max_pred_2007', 'PM25_max_pred_2008', 'PM25_max_pred_2009',
#        'PM25_max_pred_2010', 'PM25_max_pred_2011', 'PM25_max_pred_2012',
#        'PM25_max_pred_2013', 'PM25_max_pred_2014', 'PM25_mean_pred_2001',
#        'PM25_mean_pred_2002', 'PM25_mean_pred_2003', 'PM25_mean_pred_2004',
#        'PM25_mean_pred_2005', 'PM25_mean_pred_2006', 'PM25_mean_pred_2007',
#        'PM25_mean_pred_2008', 'PM25_mean_pred_2009', 'PM25_mean_pred_2010',
#        'PM25_mean_pred_2011', 'PM25_mean_pred_2012', 'PM25_mean_pred_2013',
#        'PM25_mean_pred_2014', 'PM25_med_pred_2001', 'PM25_med_pred_2002',
#        'PM25_med_pred_2003', 'PM25_med_pred_2004', 'PM25_med_pred_2005',
#        'PM25_med_pred_2006', 'PM25_med_pred_2007', 'PM25_med_pred_2008',
#        'PM25_med_pred_2009', 'PM25_med_pred_2010', 'PM25_med_pred_2011',
#        'PM25_med_pred_2012', 'PM25_med_pred_2013', 'PM25_med_pred_2014',
#        'O3_max_pred_2001', 'O3_max_pred_2002', 'O3_max_pred_2003',
#        'O3_max_pred_2004', 'O3_max_pred_2005', 'O3_max_pred_2006',
#        'O3_max_pred_2007', 'O3_max_pred_2008', 'O3_max_pred_2009',
#        'O3_max_pred_2010', 'O3_max_pred_2011', 'O3_max_pred_2012',
#        'O3_max_pred_2013', 'O3_max_pred_2014', 'O3_mean_pred_2001',
#        'O3_mean_pred_2002', 'O3_mean_pred_2003', 'O3_mean_pred_2004',
#        'O3_mean_pred_2005', 'O3_mean_pred_2006', 'O3_mean_pred_2007',
#        'O3_mean_pred_2008', 'O3_mean_pred_2009', 'O3_mean_pred_2010',
#        'O3_mean_pred_2011', 'O3_mean_pred_2012', 'O3_mean_pred_2013',
#        'O3_mean_pred_2014', 'O3_med_pred_2001', 'O3_med_pred_2002',
#        'O3_med_pred_2003', 'O3_med_pred_2004', 'O3_med_pred_2005',
#        'O3_med_pred_2006', 'O3_med_pred_2007', 'O3_med_pred_2008',
#        'O3_med_pred_2009', 'O3_med_pred_2010', 'O3_med_pred_2011',
#        'O3_med_pred_2012', 'O3_med_pred_2013', 'O3_med_pred_2014'],
#       dtype='object')

# %%
# get final row count to check for dups

len(final_df)
# Out:
# 1048

# %%
final_df.head()
# Out:
#    FIPS recent_trend  PM25_max_pred  PM25_med_pred  PM25_mean_pred  \
# 0  1101      falling      12.555164      12.013325       11.958884
# 1  1103       stable      13.287901      12.684610       12.647047
# 2  1105       stable      11.426605      11.072150       11.079387
# 3  1107       stable      11.594499      11.146401       11.155309
# 4  1109       stable      11.352271      10.939546       10.932512
#
#    O3_max_pred  O3_med_pred  O3_mean_pred  PM25_max_pred_2001  \
# 0    41.874165    39.939759     39.977164           13.365598
# 1    43.308170    41.901690     41.888594           15.564124
# 2    39.805057    38.986625     39.022229           12.768430
# 3    39.979953    39.173487     39.137133           13.199240
# 4    40.690546    39.856677     39.866958           12.164619
#
#    PM25_max_pred_2002  ...  O3_med_pred_2005  O3_med_pred_2006  \
# 0           12.650435  ...         40.567937         43.333084
# 1           14.211956  ...         43.226680         44.786660
# 2           11.553522  ...         40.612558         43.447473
# 3           11.938396  ...         41.574587         43.677365
# 4           11.319407  ...         40.589950         43.572161
#
#    O3_med_pred_2007  O3_med_pred_2008  O3_med_pred_2009  O3_med_pred_2010  \
# 0         43.589498         40.750847         36.326936         41.478252
# 1         46.470120         42.158683         38.435499         42.927004
# 2         43.062623         38.970321         34.915892         39.396689
# 3         42.648266         38.709791         35.148054         39.154417
# 4         43.102934         40.463900         36.734288         41.022877
#
#    O3_med_pred_2011  O3_med_pred_2012  O3_med_pred_2013  O3_med_pred_2014
# 0         41.055674         39.470118         36.512861         37.457633
# 1         42.164915         41.937580         38.473920         38.021493
# 2         38.999311         37.908802         35.517161         35.654156
# 3         38.971029         38.468993         36.022568         35.750203
# 4         40.996091         38.420984         36.382191         37.127240
#
# [5 rows x 92 columns]

# %%
# create df that includes null rows for pollution and ozone

null_df = pd.merge(cancer_df, pm_agg, how='left', left_on='FIPS', right_on='FIPS_pm')

null_df.head()
# Out:
#    FIPS recent_trend  FIPS_pm  PM25_max_pred  PM25_med_pred  PM25_mean_pred
# 0     0      falling      NaN            NaN            NaN             NaN
# 1  1001       stable      NaN            NaN            NaN             NaN
# 2  1003       stable      NaN            NaN            NaN             NaN
# 3  1005       stable      NaN            NaN            NaN             NaN
# 4  1007       stable      NaN            NaN            NaN             NaN

# %%
null_df = pd.merge(null_df, oz_agg, how='left', left_on='FIPS', right_on='FIPS_oz')

null_df.head()
# Out:
#    FIPS recent_trend  FIPS_pm  PM25_max_pred  PM25_med_pred  PM25_mean_pred  \
# 0     0      falling      NaN            NaN            NaN             NaN
# 1  1001       stable      NaN            NaN            NaN             NaN
# 2  1003       stable      NaN            NaN            NaN             NaN
# 3  1005       stable      NaN            NaN            NaN             NaN
# 4  1007       stable      NaN            NaN            NaN             NaN
#
#    FIPS_oz  O3_max_pred  O3_med_pred  O3_mean_pred
# 0      NaN          NaN          NaN           NaN
# 1      NaN          NaN          NaN           NaN
# 2      NaN          NaN          NaN           NaN
# 3      NaN          NaN          NaN           NaN
# 4      NaN          NaN          NaN           NaN

# %%
# check that row count matches cancer_df

len(null_df)
# Out:
# 2672

# %%
# merge in by year data

null_df = pd.merge(null_df, pm_year_agg, how='left', left_on='FIPS', right_on='FIPS_pm')

null_df = pd.merge(null_df, oz_year_agg, how='left', left_on='FIPS', right_on='FIPS_oz')

null_df.head()
# Out:
#    FIPS recent_trend  FIPS_pm_x  PM25_max_pred  PM25_med_pred  PM25_mean_pred  \
# 0     0      falling        NaN            NaN            NaN             NaN
# 1  1001       stable        NaN            NaN            NaN             NaN
# 2  1003       stable        NaN            NaN            NaN             NaN
# 3  1005       stable        NaN            NaN            NaN             NaN
# 4  1007       stable        NaN            NaN            NaN             NaN
#
#    FIPS_oz_x  O3_max_pred  O3_med_pred  O3_mean_pred  ...  O3_med_pred_2005  \
# 0        NaN          NaN          NaN           NaN  ...               NaN
# 1        NaN          NaN          NaN           NaN  ...               NaN
# 2        NaN          NaN          NaN           NaN  ...               NaN
# 3        NaN          NaN          NaN           NaN  ...               NaN
# 4        NaN          NaN          NaN           NaN  ...               NaN
#
#    O3_med_pred_2006  O3_med_pred_2007  O3_med_pred_2008  O3_med_pred_2009  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN               NaN               NaN
# 2               NaN               NaN               NaN               NaN
# 3               NaN               NaN               NaN               NaN
# 4               NaN               NaN               NaN               NaN
#
#    O3_med_pred_2010  O3_med_pred_2011  O3_med_pred_2012  O3_med_pred_2013  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN               NaN               NaN
# 2               NaN               NaN               NaN               NaN
# 3               NaN               NaN               NaN               NaN
# 4               NaN               NaN               NaN               NaN
#
#    O3_med_pred_2014
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 96 columns]

# %%
# drop dup FIPS columns and print list of cols

null_df.drop(columns=['FIPS_oz_x', 'FIPS_oz_y', 'FIPS_pm_x', 'FIPS_pm_y'], inplace=True)

null_df.columns
# Out:
# Index(['FIPS', 'recent_trend', 'PM25_max_pred', 'PM25_med_pred',
#        'PM25_mean_pred', 'O3_max_pred', 'O3_med_pred', 'O3_mean_pred',
#        'PM25_max_pred_2001', 'PM25_max_pred_2002', 'PM25_max_pred_2003',
#        'PM25_max_pred_2004', 'PM25_max_pred_2005', 'PM25_max_pred_2006',
#        'PM25_max_pred_2007', 'PM25_max_pred_2008', 'PM25_max_pred_2009',
#        'PM25_max_pred_2010', 'PM25_max_pred_2011', 'PM25_max_pred_2012',
#        'PM25_max_pred_2013', 'PM25_max_pred_2014', 'PM25_mean_pred_2001',
#        'PM25_mean_pred_2002', 'PM25_mean_pred_2003', 'PM25_mean_pred_2004',
#        'PM25_mean_pred_2005', 'PM25_mean_pred_2006', 'PM25_mean_pred_2007',
#        'PM25_mean_pred_2008', 'PM25_mean_pred_2009', 'PM25_mean_pred_2010',
#        'PM25_mean_pred_2011', 'PM25_mean_pred_2012', 'PM25_mean_pred_2013',
#        'PM25_mean_pred_2014', 'PM25_med_pred_2001', 'PM25_med_pred_2002',
#        'PM25_med_pred_2003', 'PM25_med_pred_2004', 'PM25_med_pred_2005',
#        'PM25_med_pred_2006', 'PM25_med_pred_2007', 'PM25_med_pred_2008',
#        'PM25_med_pred_2009', 'PM25_med_pred_2010', 'PM25_med_pred_2011',
#        'PM25_med_pred_2012', 'PM25_med_pred_2013', 'PM25_med_pred_2014',
#        'O3_max_pred_2001', 'O3_max_pred_2002', 'O3_max_pred_2003',
#        'O3_max_pred_2004', 'O3_max_pred_2005', 'O3_max_pred_2006',
#        'O3_max_pred_2007', 'O3_max_pred_2008', 'O3_max_pred_2009',
#        'O3_max_pred_2010', 'O3_max_pred_2011', 'O3_max_pred_2012',
#        'O3_max_pred_2013', 'O3_max_pred_2014', 'O3_mean_pred_2001',
#        'O3_mean_pred_2002', 'O3_mean_pred_2003', 'O3_mean_pred_2004',
#        'O3_mean_pred_2005', 'O3_mean_pred_2006', 'O3_mean_pred_2007',
#        'O3_mean_pred_2008', 'O3_mean_pred_2009', 'O3_mean_pred_2010',
#        'O3_mean_pred_2011', 'O3_mean_pred_2012', 'O3_mean_pred_2013',
#        'O3_mean_pred_2014', 'O3_med_pred_2001', 'O3_med_pred_2002',
#        'O3_med_pred_2003', 'O3_med_pred_2004', 'O3_med_pred_2005',
#        'O3_med_pred_2006', 'O3_med_pred_2007', 'O3_med_pred_2008',
#        'O3_med_pred_2009', 'O3_med_pred_2010', 'O3_med_pred_2011',
#        'O3_med_pred_2012', 'O3_med_pred_2013', 'O3_med_pred_2014'],
#       dtype='object')

# %%
# check that row count of df matches cancer_data

len(null_df)
# Out:
# 2672

# %%
null_df.head()
# Out:
#    FIPS recent_trend  PM25_max_pred  PM25_med_pred  PM25_mean_pred  \
# 0     0      falling            NaN            NaN             NaN
# 1  1001       stable            NaN            NaN             NaN
# 2  1003       stable            NaN            NaN             NaN
# 3  1005       stable            NaN            NaN             NaN
# 4  1007       stable            NaN            NaN             NaN
#
#    O3_max_pred  O3_med_pred  O3_mean_pred  PM25_max_pred_2001  \
# 0          NaN          NaN           NaN                 NaN
# 1          NaN          NaN           NaN                 NaN
# 2          NaN          NaN           NaN                 NaN
# 3          NaN          NaN           NaN                 NaN
# 4          NaN          NaN           NaN                 NaN
#
#    PM25_max_pred_2002  ...  O3_med_pred_2005  O3_med_pred_2006  \
# 0                 NaN  ...               NaN               NaN
# 1                 NaN  ...               NaN               NaN
# 2                 NaN  ...               NaN               NaN
# 3                 NaN  ...               NaN               NaN
# 4                 NaN  ...               NaN               NaN
#
#    O3_med_pred_2007  O3_med_pred_2008  O3_med_pred_2009  O3_med_pred_2010  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN               NaN               NaN
# 2               NaN               NaN               NaN               NaN
# 3               NaN               NaN               NaN               NaN
# 4               NaN               NaN               NaN               NaN
#
#    O3_med_pred_2011  O3_med_pred_2012  O3_med_pred_2013  O3_med_pred_2014
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN               NaN               NaN
# 2               NaN               NaN               NaN               NaN
# 3               NaN               NaN               NaN               NaN
# 4               NaN               NaN               NaN               NaN
#
# [5 rows x 92 columns]

# %%
#obscure connection info from github by importing info from csv

conn_path = "/content/drive/MyDrive/Data/db_conn_info.csv"

conn_info = pd.read_csv(conn_path)

db_name = conn_info['db_name'][0]

db_pw = conn_info['password'][0]

db_host = conn_info['host'][0]

db_port = conn_info['port'][0]

db_user = conn_info['user'][0]

# %%
from sqlalchemy import create_engine

engine = create_engine(f'postgresql://{db_name}:{db_pw}@{db_host}:{db_port}/{db_user}')

# %%
# upload data to elephant db

final_df.to_sql('model_dataset', engine, if_exists='replace')

# %%
null_df.to_sql('null_model_dataset', engine, if_exists='replace')
