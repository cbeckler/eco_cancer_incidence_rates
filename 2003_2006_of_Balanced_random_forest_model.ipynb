# %% [markdown]
# <a href="https://colab.research.google.com/github/cbeckler/final_project/blob/cw_mlm/2003_2006_of_Balanced_random_forest_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
# Find the latest version of spark 3.0 from http://www.apache.org/dist/spark/ and enter as the spark version
# For example:
# spark_version = 'spark-3.0.3'
spark_version = 'spark-3.1.3'
os.environ['SPARK_VERSION']=spark_version

# Install Spark and Java
# !apt-get update
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q http://www.apache.org/dist/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop2.7.tgz
# !tar xf $SPARK_VERSION-bin-hadoop2.7.tgz
# !pip install -q findspark

# Set Environment Variables
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-hadoop2.7"

# Start a SparkSession
import findspark
findspark.init()
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:2 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:3 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:10 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [1,371 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [3,145 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,568 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,573 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [1,412 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,351 kB]
# Fetched 13.7 MB in 4s (3,370 kB/s)
# Reading package lists... Done

# %%
# Download the Postgres driver that will allow Spark to interact with Postgres.
# !wget https://jdbc.postgresql.org/download/postgresql-42.2.16.jar
# Out:
# --2023-01-16 23:14:01--  https://jdbc.postgresql.org/download/postgresql-42.2.16.jar
# Resolving jdbc.postgresql.org (jdbc.postgresql.org)... 72.32.157.228, 2001:4800:3e1:1::228
# Connecting to jdbc.postgresql.org (jdbc.postgresql.org)|72.32.157.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1002883 (979K) [application/java-archive]
# Saving to: ‘postgresql-42.2.16.jar’
#
# postgresql-42.2.16. 100%[===================>] 979.38K  1.98MB/s    in 0.5s
#
# 2023-01-16 23:14:02 (1.98 MB/s) - ‘postgresql-42.2.16.jar’ saved [1002883/1002883]

# %%
# start spark session 
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("balanced_random_forest").config("spark.driver.extraClassPath","/content/postgresql-42.2.16.jar").getOrCreate()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#connect to database

import pandas as pd

conn_path = "/content/drive/MyDrive/Data/db_conn_info.csv"

conn_info = pd.read_csv(conn_path)

db_name = conn_info['db_name'][0]

db_pw = conn_info['password'][0]

db_host = conn_info['host'][0]

db_port = conn_info['port'][0]

db_user = conn_info['user'][0]

# %%
from sqlalchemy import create_engine

engine = create_engine(f'postgresql://{db_name}:{db_pw}@{db_host}:{db_port}/{db_user}')

# %%
# import model dataset

df = pd.read_sql("select * from model_dataset", engine)

df.head()
# Out:
#    index  FIPS recent_trend  PM25_max_pred  PM25_med_pred  PM25_mean_pred  \
# 0      0  1101      falling      12.555164      12.013325       11.958884
# 1      1  1103       stable      13.287901      12.684610       12.647047
# 2      2  1105       stable      11.426605      11.072150       11.079387
# 3      3  1107       stable      11.594499      11.146401       11.155309
# 4      4  1109       stable      11.352271      10.939546       10.932512
#
#    O3_max_pred  O3_med_pred  O3_mean_pred  PM25_max_pred_2001  ...  \
# 0    41.874165    39.939759     39.977164           13.365598  ...
# 1    43.308170    41.901690     41.888594           15.564124  ...
# 2    39.805057    38.986625     39.022229           12.768430  ...
# 3    39.979953    39.173487     39.137133           13.199240  ...
# 4    40.690546    39.856677     39.866958           12.164619  ...
#
#    O3_med_pred_2005  O3_med_pred_2006  O3_med_pred_2007  O3_med_pred_2008  \
# 0         40.567937         43.333084         43.589498         40.750847
# 1         43.226680         44.786660         46.470120         42.158683
# 2         40.612558         43.447473         43.062623         38.970321
# 3         41.574587         43.677365         42.648266         38.709791
# 4         40.589950         43.572161         43.102934         40.463900
#
#    O3_med_pred_2009  O3_med_pred_2010  O3_med_pred_2011  O3_med_pred_2012  \
# 0         36.326936         41.478252         41.055674         39.470118
# 1         38.435499         42.927004         42.164915         41.937580
# 2         34.915892         39.396689         38.999311         37.908802
# 3         35.148054         39.154417         38.971029         38.468993
# 4         36.734288         41.022877         40.996091         38.420984
#
#    O3_med_pred_2013  O3_med_pred_2014
# 0         36.512861         37.457633
# 1         38.473920         38.021493
# 2         35.517161         35.654156
# 3         36.022568         35.750203
# 4         36.382191         37.127240
#
# [5 rows x 93 columns]

# %%
import numpy as np
from collections import Counter
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE

# %% [markdown]
# ## Create Features and target variable

# %%
X = df.drop(['index', 'FIPS', 'recent_trend'], axis=1)
y = df['recent_trend']

# %%
y.value_counts()
# Out:
# stable     1922
# falling     136
# rising       38
# Name: recent_trend, dtype: int64

# %% [markdown]
# ## Data split into Training and Testing

# %%
#Split data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    random_state=1,
                                                    stratify=y)
scaler =StandardScaler().fit(X_train)

X_train_scaled =scaler.transform(X_train)
X_test_scaled =scaler.transform(X_test)

# %% [markdown]
# ## Data resampled with SMOTE

# %%
# Resampling training data with SMOTE
X_resampled, y_resampled = SMOTE(
    random_state=1,sampling_strategy='auto').fit_resample(
    X_train_scaled, y_train)

print(f'y_resampled: {Counter(y_resampled)}')
# Out:
# y_resampled: Counter({'stable': 1441, 'falling': 1441, 'rising': 1441})

# %% [markdown]
# ## Balanced Random Forest Classifier

# %%
from imblearn.ensemble import BalancedRandomForestClassifier
brc=BalancedRandomForestClassifier(random_state=1, n_estimators=100).fit(X_resampled, y_resampled)

# %%
y_pred= brc.predict(X_test_scaled)

# %%
y_pred_train= brc.predict(X_train_scaled)

# %% [markdown]
# ## Balanced Accuracy Score

# %%
# Balanced accuracy training score 
balanced_accuracy_score(y_train, y_pred_train)
# Out:
# 1.0

# %%
# Balanced accuracy testign score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.9187966246789777

# %% [markdown]
# ## Confusion Matrix

# %%
cm=confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 26,   0,   8],
#        [  0,   9,   0],
#        [  4,   0, 477]])

# %%
brc_df=pd.DataFrame({"Prediction": y_pred, "Actual": y_test}).reset_index(drop=True)
brc_df.head()
# Out:
#   Prediction   Actual
# 0     stable   stable
# 1     stable   stable
# 2     stable   stable
# 3     stable   stable
# 4    falling  falling

# %%
print(brc_df.Prediction.value_counts())
print(brc_df.Actual.value_counts())
# Out:
# stable     485
# falling     30
# rising       9
# Name: Prediction, dtype: int64
# stable     481
# falling     34
# rising       9
# Name: Actual, dtype: int64

# %% [markdown]
# ## Imbalanced Classification Report

# %%
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#     falling       0.87      0.76      0.99      0.81      0.87      0.74        34
#      rising       1.00      1.00      1.00      1.00      1.00      1.00         9
#      stable       0.98      0.99      0.81      0.99      0.90      0.82       481
#
# avg / total       0.98      0.98      0.83      0.98      0.90      0.82       524

# %% [markdown]
# # Predictions with trained model

# %%
scaler =StandardScaler().fit(X)
X_scaled =scaler.transform(X)

# %%
prediction_trend= brc.predict(X_scaled)

# %%
prediction_trend
# Out:
# array(['falling', 'stable', 'stable', ..., 'stable', 'stable', 'stable'],
#       dtype=object)

# %%
# create list of new col names to replace specific year values

col_list = [name for name in df.columns]

new_col_names = []

for col in col_list:

  if '2003' in col:
    new_name = col.replace('2003', 'Y3')
    new_col_names.append(new_name)
  elif '2004' in col:
    new_name = col.replace('2004', 'Y4')
    new_col_names.append(new_name)
  elif '2005' in col:
    new_name = col.replace('2005', 'Y5')
    new_col_names.append(new_name)
  elif '2006' in col:
    new_name = col.replace('2006', 'Y6')
    new_col_names.append(new_name)
  elif '2007' in col:
    new_name = col.replace('2007', 'Y7')
    new_col_names.append(new_name)
  elif '2008' in col:
    new_name = col.replace('2008', 'Y8')
    new_col_names.append(new_name)
  elif '2009' in col:
    new_name = col.replace('2009', 'Y9')
    new_col_names.append(new_name)
  elif '2010' in col:
    new_name = col.replace('2010', 'Y10')
    new_col_names.append(new_name)
  elif '2011' in col:
    new_name = col.replace('2011', 'Y11')
    new_col_names.append(new_name)
  elif '2012' in col:
    new_name = col.replace('2012', 'Y12')
    new_col_names.append(new_name)
  elif '2013' in col:
    new_name = col.replace('2013', 'Y13')
    new_col_names.append(new_name)
  elif '2014' in col:
    new_name = col.replace('2014', 'Y14')
    new_col_names.append(new_name)
  elif '2015' in col:
    new_name = col.replace('2015', 'Y15')
    new_col_names.append(new_name)
  elif '2016' in col:
    new_name = col.replace('2016', 'Y16')
    new_col_names.append(new_name)
  else:
    new_col_names.append(col)

new_col_names
# Out:
# ['index',
#  'FIPS',
#  'recent_trend',
#  'prediction_trend',
#  'PM25_max_pred',
#  'PM25_med_pred',
#  'PM25_mean_pred',
#  'O3_max_pred',
#  'O3_med_pred',
#  'O3_mean_pred',
#  'PM25_max_pred_2001',
#  'PM25_max_pred_2002',
#  'PM25_max_pred_Y3',
#  'PM25_max_pred_Y4',
#  'PM25_max_pred_Y5',
#  'PM25_max_pred_Y6',
#  'PM25_max_pred_Y7',
#  'PM25_max_pred_Y8',
#  'PM25_max_pred_Y9',
#  'PM25_max_pred_Y10',
#  'PM25_max_pred_Y11',
#  'PM25_max_pred_Y12',
#  'PM25_max_pred_Y13',
#  'PM25_max_pred_Y14',
#  'PM25_mean_pred_2001',
#  'PM25_mean_pred_2002',
#  'PM25_mean_pred_Y3',
#  'PM25_mean_pred_Y4',
#  'PM25_mean_pred_Y5',
#  'PM25_mean_pred_Y6',
#  'PM25_mean_pred_Y7',
#  'PM25_mean_pred_Y8',
#  'PM25_mean_pred_Y9',
#  'PM25_mean_pred_Y10',
#  'PM25_mean_pred_Y11',
#  'PM25_mean_pred_Y12',
#  'PM25_mean_pred_Y13',
#  'PM25_mean_pred_Y14',
#  'PM25_med_pred_2001',
#  'PM25_med_pred_2002',
#  'PM25_med_pred_Y3',
#  'PM25_med_pred_Y4',
#  'PM25_med_pred_Y5',
#  'PM25_med_pred_Y6',
#  'PM25_med_pred_Y7',
#  'PM25_med_pred_Y8',
#  'PM25_med_pred_Y9',
#  'PM25_med_pred_Y10',
#  'PM25_med_pred_Y11',
#  'PM25_med_pred_Y12',
#  'PM25_med_pred_Y13',
#  'PM25_med_pred_Y14',
#  'O3_max_pred_2001',
#  'O3_max_pred_2002',
#  'O3_max_pred_Y3',
#  'O3_max_pred_Y4',
#  'O3_max_pred_Y5',
#  'O3_max_pred_Y6',
#  'O3_max_pred_Y7',
#  'O3_max_pred_Y8',
#  'O3_max_pred_Y9',
#  'O3_max_pred_Y10',
#  'O3_max_pred_Y11',
#  'O3_max_pred_Y12',
#  'O3_max_pred_Y13',
#  'O3_max_pred_Y14',
#  'O3_mean_pred_2001',
#  'O3_mean_pred_2002',
#  'O3_mean_pred_Y3',
#  'O3_mean_pred_Y4',
#  'O3_mean_pred_Y5',
#  'O3_mean_pred_Y6',
#  'O3_mean_pred_Y7',
#  'O3_mean_pred_Y8',
#  'O3_mean_pred_Y9',
#  'O3_mean_pred_Y10',
#  'O3_mean_pred_Y11',
#  'O3_mean_pred_Y12',
#  'O3_mean_pred_Y13',
#  'O3_mean_pred_Y14',
#  'O3_med_pred_2001',
#  'O3_med_pred_2002',
#  'O3_med_pred_Y3',
#  'O3_med_pred_Y4',
#  'O3_med_pred_Y5',
#  'O3_med_pred_Y6',
#  'O3_med_pred_Y7',
#  'O3_med_pred_Y8',
#  'O3_med_pred_Y9',
#  'O3_med_pred_Y10',
#  'O3_med_pred_Y11',
#  'O3_med_pred_Y12',
#  'O3_med_pred_Y13',
#  'O3_med_pred_Y14']

# %%
# apply new col names

df.columns = new_col_names

# %%
df['prediction_trend']= prediction_trend
df=df[['index',
 'FIPS',
 'recent_trend',
 'prediction_trend',
 'PM25_max_pred',
 'PM25_med_pred',
 'PM25_mean_pred',
 'O3_max_pred',
 'O3_med_pred',
 'O3_mean_pred',
 'PM25_max_pred_2003',
 'PM25_max_pred_2004',
 'PM25_max_pred_2005',
 'PM25_max_pred_2006',
 'PM25_max_pred_2007',
 'PM25_max_pred_2008',
 'PM25_max_pred_2009',
 'PM25_max_pred_2010',
 'PM25_max_pred_2011',
 'PM25_max_pred_2012',
 'PM25_max_pred_2013',
 'PM25_max_pred_2014',
 'PM25_max_pred_2015',
 'PM25_max_pred_2016',
 'PM25_mean_pred_2003',
 'PM25_mean_pred_2004',
 'PM25_mean_pred_2005',
 'PM25_mean_pred_2006',
 'PM25_mean_pred_2007',
 'PM25_mean_pred_2008',
 'PM25_mean_pred_2009',
 'PM25_mean_pred_2010',
 'PM25_mean_pred_2011',
 'PM25_mean_pred_2012',
 'PM25_mean_pred_2013',
 'PM25_mean_pred_2014',
 'PM25_mean_pred_2015',
 'PM25_mean_pred_2016',
 'PM25_med_pred_2003',
 'PM25_med_pred_2004',
 'PM25_med_pred_2005',
 'PM25_med_pred_2006',
 'PM25_med_pred_2007',
 'PM25_med_pred_2008',
 'PM25_med_pred_2009',
 'PM25_med_pred_2010',
 'PM25_med_pred_2011',
 'PM25_med_pred_2012',
 'PM25_med_pred_2013',
 'PM25_med_pred_2014',
 'PM25_med_pred_2015',
 'PM25_med_pred_2016',
 'O3_max_pred_2003',
 'O3_max_pred_2004',
 'O3_max_pred_2005',
 'O3_max_pred_2006',
 'O3_max_pred_2007',
 'O3_max_pred_2008',
 'O3_max_pred_2009',
 'O3_max_pred_2010',
 'O3_max_pred_2011',
 'O3_max_pred_2012',
 'O3_max_pred_2013',
 'O3_max_pred_2014',
 'O3_max_pred_2015',
 'O3_max_pred_2016',
 'O3_mean_pred_2003',
 'O3_mean_pred_2004',
 'O3_mean_pred_2005',
 'O3_mean_pred_2006',
 'O3_mean_pred_2007',
 'O3_mean_pred_2008',
 'O3_mean_pred_2009',
 'O3_mean_pred_2010',
 'O3_mean_pred_2011',
 'O3_mean_pred_2012',
 'O3_mean_pred_2013',
 'O3_mean_pred_2014',
 'O3_mean_pred_2015',
 'O3_mean_pred_2016',
 'O3_med_pred_2003',
 'O3_med_pred_2004',
 'O3_med_pred_2005',
 'O3_med_pred_2006',
 'O3_med_pred_2007',
 'O3_med_pred_2008',
 'O3_med_pred_2009',
 'O3_med_pred_2010',
 'O3_med_pred_2011',
 'O3_med_pred_2012',
 'O3_med_pred_2013',
 'O3_med_pred_2014',
 'O3_med_pred_2015',
 'O3_med_pred_2016',]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-9137755bcd04> in <module>
#       1 df['prediction_trend']= prediction_trend
# ----> 2 df=df[['index',
#       3  'FIPS',
#       4  'recent_trend',
#       5  'prediction_trend',
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['PM25_max_pred_2003', 'PM25_max_pred_2004', 'PM25_max_pred_2005', 'PM25_max_pred_2006', 'PM25_max_pred_2007', 'PM25_max_pred_2008', 'PM25_max_pred_2009', 'PM25_max_pred_2010', 'PM25_max_pred_2011', 'PM25_max_pred_2012', 'PM25_max_pred_2013', 'PM25_max_pred_2014', 'PM25_max_pred_2015', 'PM25_max_pred_2016', 'PM25_mean_pred_2003', 'PM25_mean_pred_2004', 'PM25_mean_pred_2005', 'PM25_mean_pred_2006', 'PM25_mean_pred_2007', 'PM25_mean_pred_2008', 'PM25_mean_pred_2009', 'PM25_mean_pred_2010', 'PM25_mean_pred_2011', 'PM25_mean_pred_2012', 'PM25_mean_pred_2013', 'PM25_mean_pred_2014', 'PM25_mean_pred_2015', 'PM25_mean_pred_2016', 'PM25_med_pred_2003', 'PM25_med_pred_2004', 'PM25_med_pred_2005', 'PM25_med_pred_2006', 'PM25_med_pred_2007', 'PM25_med_pred_2008', 'PM25_med_pred_2009', 'PM25_med_pred_2010', 'PM25_med_pred_2011', 'PM25_med_pred_2012', 'PM25_med_pred_2013', 'PM25_med_pred_2014', 'PM25_med_pred_2015', 'PM25_med_pred_2016', 'O3_max_pred_2003', 'O3_max_pred_2004', 'O3_max_pred_2005', 'O3_max_pred_2006', 'O3_max_pred_2007', 'O3_max_pred_2008', 'O3_max_pred_2009', 'O3_max_pred_2010', 'O3_max_pred_2011', 'O3_max_pred_2012', 'O3_max_pred_2013', 'O3_max_pred_2014', 'O3_max_pred_2015', 'O3_max_pred_2016', 'O3_mean_pred_2003', 'O3_mean_pred_2004', 'O3_mean_pred_2005', 'O3_mean_pred_2006', 'O3_mean_pred_2007', 'O3_mean_pred_2008', 'O3_mean_pred_2009', 'O3_mean_pred_2010', 'O3_mean_pred_2011', 'O3_mean_pred_2012', 'O3_mean_pred_2013', 'O3_mean_pred_2014', 'O3_...

# %%
df.head()
# df.to_csv('/content/drive/MyDrive/Final_Project/df.csv')
# Out:
#    index  FIPS recent_trend prediction_trend  PM25_max_pred  PM25_med_pred  \
# 0      0  1101      falling          falling      12.555164      12.013325
# 1      1  1103       stable           stable      13.287901      12.684610
# 2      2  1105       stable           stable      11.426605      11.072150
# 3      3  1107       stable           stable      11.594499      11.146401
# 4      4  1109       stable           stable      11.352271      10.939546
#
#    PM25_mean_pred  O3_max_pred  O3_med_pred  O3_mean_pred  ...  \
# 0       11.958884    41.874165    39.939759     39.977164  ...
# 1       12.647047    43.308170    41.901690     41.888594  ...
# 2       11.079387    39.805057    38.986625     39.022229  ...
# 3       11.155309    39.979953    39.173487     39.137133  ...
# 4       10.932512    40.690546    39.856677     39.866958  ...
#
#    O3_med_pred_2005  O3_med_pred_2006  O3_med_pred_2007  O3_med_pred_2008  \
# 0         40.567937         43.333084         43.589498         40.750847
# 1         43.226680         44.786660         46.470120         42.158683
# 2         40.612558         43.447473         43.062623         38.970321
# 3         41.574587         43.677365         42.648266         38.709791
# 4         40.589950         43.572161         43.102934         40.463900
#
#    O3_med_pred_2009  O3_med_pred_2010  O3_med_pred_2011  O3_med_pred_2012  \
# 0         36.326936         41.478252         41.055674         39.470118
# 1         38.435499         42.927004         42.164915         41.937580
# 2         34.915892         39.396689         38.999311         37.908802
# 3         35.148054         39.154417         38.971029         38.468993
# 4         36.734288         41.022877         40.996091         38.420984
#
#    O3_med_pred_2013  O3_med_pred_2014
# 0         36.512861         37.457633
# 1         38.473920         38.021493
# 2         35.517161         35.654156
# 3         36.022568         35.750203
# 4         36.382191         37.127240
#
# [5 rows x 94 columns]

# %%
print(df.recent_trend.value_counts())
print(df.prediction_trend.value_counts())
# Out:
# stable     1922
# falling     136
# rising       38
# Name: recent_trend, dtype: int64
# stable     1922
# falling     132
# rising       42
# Name: prediction_trend, dtype: int64

# %% [markdown]
# ## Feature importances

# %%
# List the features sorted in descending order by feature importance
features = sorted(zip(X.columns, brc.feature_importances_), reverse= True, key = lambda x: x[1])
for feature in features:
    print(f'{feature[0]}:{feature[1]}')
# Out:
# O3_max_pred_2009:0.039061295891259444
# O3_max_pred_2004:0.031782799985942696
# O3_max_pred_2014:0.029128220011931917
# O3_mean_pred_2009:0.02529611653099427
# O3_max_pred_2006:0.02270927889400338
# PM25_max_pred_2011:0.021121177058082332
# O3_med_pred_2009:0.02060528576499261
# O3_max_pred_2013:0.019082979104752467
# PM25_max_pred_2007:0.018027508023366556
# O3_mean_pred_2006:0.017135802857086088
# O3_med_pred_2013:0.01711214381593818
# O3_med_pred_2003:0.016622103873330366
# O3_max_pred:0.01657172061575965
# PM25_max_pred_2004:0.016192984000404413
# O3_max_pred_2011:0.01597196191067247
# O3_max_pred_2007:0.015635510968216585
# O3_med_pred_2004:0.014484646776642265
# O3_max_pred_2001:0.014441766851475822
# PM25_max_pred_2001:0.01443803213794468
# O3_mean_pred_2004:0.014431137005396857
# PM25_max_pred_2002:0.013664104887568489
# O3_max_pred_2005:0.0135700926275771
# O3_max_pred_2008:0.013296752020324392
# O3_max_pred_2003:0.013273225746323392
# O3_mean_pred_2007:0.01324693111900283
# O3_max_pred_2012:0.012688519675170571
# O3_med_pred_2006:0.012611591176129507
# O3_mean_pred_2013:0.012406423683860024
# O3_mean_pred:0.012219670197599593
# O3_mean_pred_2001:0.012198791803776466
# O3_mean_pred_2003:0.01211460938356303
# O3_med_pred_2007:0.011695019792580157
# O3_med_pred_2001:0.011454660814478955
# O3_med_pred_2014:0.010702189336572698
# PM25_med_pred_2007:0.010640746182449569
# PM25_max_pred_2013:0.010561773023294606
# O3_mean_pred_2014:0.010403303535220572
# PM25_mean_pred_2014:0.010400057176252066
# PM25_max_pred_2012:0.010337985161160492
# O3_med_pred_2012:0.010333601579378786
# O3_mean_pred_2010:0.010003807826902857
# O3_mean_pred_2008:0.009847934039788056
# O3_mean_pred_2012:0.009679434018679477
# PM25_max_pred:0.009596968698311541
# O3_max_pred_2002:0.009240169015801433
# PM25_max_pred_2006:0.009008591424769912
# PM25_max_pred_2008:0.0089670349591897
# PM25_med_pred_2011:0.008950012569303169
# PM25_med_pred_2002:0.008555352045115839
# PM25_med_pred_2014:0.00833968902633902
# PM25_mean_pred_2011:0.008213030021409209
# O3_med_pred:0.008192026628553515
# PM25_max_pred_2014:0.00818764357250996
# O3_mean_pred_2011:0.00816696954568377
# O3_med_pred_2010:0.008093650126531224
# O3_max_pred_2010:0.007963713328639772
# PM25_mean_pred_2005:0.007941546756095008
# O3_med_pred_2005:0.00793278473406488
# PM25_mean_pred_2007:0.007919567889343766
# O3_med_pred_2002:0.007838680234748374
# PM25_max_pred_2003:0.007729546183707303
# PM25_mean_pred_2001:0.007698649517723583
# PM25_med_pred_2004:0.0075257089938211945
# O3_mean_pred_2005:0.007444396535632702
# PM25_med_pred_2003:0.00737444175944789
# PM25_mean_pred_2002:0.007332040999628217
# O3_mean_pred_2002:0.007311169602102349
# O3_med_pred_2008:0.007271185582444484
# PM25_med_pred_2005:0.007192374813325067
# PM25_med_pred_2009:0.0070990868166531055
# PM25_med_pred_2013:0.0068636283132334774
# O3_med_pred_2011:0.006774041160699196
# PM25_med_pred_2012:0.006690546781987299
# PM25_max_pred_2005:0.006543477482625005
# PM25_mean_pred_2004:0.006428046682679918
# PM25_mean_pred_2009:0.006316287268373786
# PM25_mean_pred:0.006195022701338882
# PM25_mean_pred_2013:0.006053394306902118
# PM25_mean_pred_2006:0.006021378123189786
# PM25_mean_pred_2012:0.005937813170370212
# PM25_med_pred_2001:0.005784743369383874
# PM25_max_pred_2010:0.005649941936965762
# PM25_med_pred_2010:0.005604567021289894
# PM25_mean_pred_2003:0.00556963562670122
# PM25_med_pred:0.005359499391464534
# PM25_max_pred_2009:0.0052385277058052855
# PM25_med_pred_2006:0.005165687856989192
# PM25_mean_pred_2010:0.005036106756521394
# PM25_med_pred_2008:0.0044394588612806304
# PM25_mean_pred_2008:0.004038467215455783

# %%
import matplotlib.pyplot as plt
features = sorted(zip(X.columns, brc.feature_importances_), key = lambda x: x[1])
cols = [f[0] for f in features]
width = [f[1] for f in features]

fig, ax = plt.subplots()

fig.set_size_inches(5,50)
plt.margins(y=0.001)

ax.barh(y=cols, width=width)
# plt.savefig('/content/drive/MyDrive/Final_Project/Feature_Importances')
plt.show()

# %%
from sklearn.inspection import permutation_importance
result = permutation_importance(
    brc, X_test_scaled, y_test, n_repeats=10, random_state=1, n_jobs=2)

forest_importances = pd.Series(result.importances_mean)

# %%
import matplotlib.pylab as pylab

fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=result.importances_std, ax=ax)
# for name, forest_importances in zip(["train", "test"], [train_importances, test_importances]):

ax.set_title("Feature importances using permutation on full model",fontdict={'fontsize': 100, 'fontweight': 'semibold'})
ax.set_ylabel("Mean accuracy decrease",fontdict={'fontsize': 70, 'fontweight': 'semibold'})
ax.invert_yaxis()
fig.set_size_inches(100,30)
plt.margins(x=0.00001,y=0.00001)


# plt.savefig('/content/drive/MyDrive/Final_Project/Forest_Importances')
plt.show()

# %%
from sklearn.inspection import permutation_importance
result = permutation_importance(
    brc, X_test_scaled, y_test, n_repeats=10, random_state=1, n_jobs=2
)

sorted_importances_idx = result.importances_mean.argsort()

importances = pd.DataFrame(
    result.importances[sorted_importances_idx].T,
    columns=X.columns[sorted_importances_idx],
)
ax = importances.plot.box(vert=False, whis=10)
ax.set_title("Permutation Importances (test set)")
ax.axvline(x=0, color="k", linestyle="--")
ax.set_xlabel("Decrease in accuracy score")
width = 5
height = 20
ax.figure.set_size_inches(width, height)
